# %% [markdown]
# # Дискретное вейвлет преобразование
#
# Были взяты данные магнитной обсерватории "Паратунка" за 2017 год.
# <br>Выборка данных основывалась на K-index и распределялись следующим образом:
# |       Значение      |      Состояние         |
# |--------------|------------------------|
# | K≤=2 и менее | спокойное              |
# | K=2…3        | слабо возмущенное      |
# | K=4          | возмущенное            |
# | K=5…6        | магнитная буря         |
# | K≥=7 и более | большая магнитная буря |
#
#
# Спокойное поле
#
# - 2017-10-09
# - 2017-12-22
# - 2017-11-06
# - 2017-02-14
# - 2017-12-03
#
# Слабовозмущенное поле
#
# - 2017-09-10
# - 2017-12-02
# - 2017-01-17
# - 2017-11-25
# - 2017-04-27
#
# Возмущенное поле
#
# - 2017-05-04
# - 2017-11-24
# - 2017-11-17
# - 2017-02-16
# - 2017-01-09
#
# Магнитные бури
#
# - 2017-05-27
# - 2017-03-10
# - 2017-10-24
# - 2017-09-13
# - 2017-07-22
#
# Большие магнитные бури
#
# - 2017-09-07
# - 2017-09-08
#
# ### Данные H - компоненты 2017-10-09
#
# ![image.png](attachment:image.png)
#
# #### Дискретное вейвлет преобразование
#
# ![image-2.png](attachment:image-2.png)
#
# ### Данные H - компоненты 2017-04-27
#
# ![image-3.png](attachment:image-3.png)
#
# #### Дискретное вейвлет преобразование
# ![image-4.png](attachment:image-4.png)
#
# ### Данные H-компоненты 2017-05-04
# ![image-5.png](attachment:image-5.png)
#
# #### Дискретное вейвлет преобразование
# ![image-6.png](attachment:image-6.png)
#
# ### Данные H-компоненты 2017-05-27
# ![image-7.png](attachment:image-7.png)
#
# #### Дискретное вейвлет преобразование
# ![image-8.png](attachment:image-8.png)
#
# ### Данные H-компоненты 7-8 сентября 2017
# ![image-12.png](attachment:image-12.png)
# #### Дискретное вейвлет преобразование
# ![image-13.png](attachment:image-13.png)
#
# ### Кратномасштабное вейвлет преобразование
# #### Использованы данные H-компоненты 7-8 сентября (сильная магнитная буря)
# ![image-9.png](attachment:image-9.png)
