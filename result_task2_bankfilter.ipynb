# %% [markdown]
# Вейвлет функция | АЧХ
# --- | ---
# ![image-13.png](attachment:image-13.png)| ![image.png](attachment:image.png)
#  ![image-12.png](attachment:image-12.png)| ![image-2.png](attachment:image-2.png)
#  ![image-14.png](attachment:image-14.png)| ![image-3.png](attachment:image-3.png)
#  ![image-15.png](attachment:image-15.png)| ![image-4.png](attachment:image-4.png)
#  ![image-16.png](attachment:image-16.png)| ![image-5.png](attachment:image-5.png)
#  ![image-17.png](attachment:image-17.png)| ![image-6.png](attachment:image-6.png)
#  ![image-18.png](attachment:image-18.png)| ![image-7.png](attachment:image-7.png)
#  ![image-19.png](attachment:image-19.png)| ![image-8.png](attachment:image-8.png)
#  ![image-20.png](attachment:image-20.png)| ![image-9.png](attachment:image-9.png)
#  ![image-21.png](attachment:image-21.png)| ![image-10.png](attachment:image-10.png)
#  ![image-22.png](attachment:image-22.png)| ![image-11.png](attachment:image-11.png)
