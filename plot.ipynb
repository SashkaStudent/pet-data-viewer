# %%
import app
import numpy
import matplotlib.pyplot as plot
import pywt

y = (app.s["PETH"].values)
cA, cD = pywt.dwt(y, 'db2')
res = pywt.idwt(cA, None, 'db2')

plot.subplot(313)
plot.plot(range(0,1440),y)
plot.subplot(311)

plot.plot(cA)

plot.subplot(312)

plot.plot(cD)
plot.show()

# %%
import numpy
import matplotlib.pyplot as plot
import pywt

y = (app.s["PETH"].values)
plot.plot(y)
